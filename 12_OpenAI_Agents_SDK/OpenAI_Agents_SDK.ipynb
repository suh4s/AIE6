# %% [markdown]
# <p align = "center" draggable=”false” ><img src="https://github.com/AI-Maker-Space/LLM-Dev-101/assets/37101144/d1343317-fa2f-41e1-8af1-1dbb18399719"
#      width="200px"
#      height="auto"/>
# </p>
#
# <h1 align="center" id="heading">OpenAI Agents SDK - AIM</h1>
#
# In this notebook, we'll go over some of the key features of the OpenAI Agents SDK - as explored through a notebook-ified version of their [Research Bot](https://github.com/openai/openai-agents-python/tree/main/examples/research_bot).

# %%
### You don't need to run this cell if you're running this notebook locally.

# !pip install -qU openai-agents
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.2 MB/s eta 0:00:00

# %% [markdown]
# API Key:

# %%
import os
import getpass
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY') #getpass.getpass()

# %% [markdown]
# Nest Async:

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Agents
#
# As may be expected, the primary thing we'll do in the Agents SDK is construct Agents!
#
# Agents are constructed with a few basic properties:
#
# - A prompt, which OpenAI is using the language "instruction" for, that determines the behaviour or goal of the Agent
# - A model, the "brain" of the Agent
#
# They also typically include an additional property:
#
# - Tool(s) that equip the Agent with things it can use to get stuff done

# %% [markdown]
# ### Task 1: Create Planner Agent
#
# Let's start by creating our "Planner Agent" - which will come up with the initial set of search terms that should answer a query provided by the user.

# %%
from pydantic import BaseModel
from agents import Agent

PLANNER_PROMPT = (
    "You are a helpful research assistant. Given a query, come up with a set of web searches to perform"
    "to best answer the query. Output between 5 and 20 terms to query for."
)

# %% [markdown]
# Next, we'll define the data models that our Planner Agent will use to structure its output. We'll create:
#
# 1. `WebSearchItem` - A model for individual search items, containing the search query and reasoning
# 2. `WebSearchPlan` - A container model that holds a list of search items
#
# These Pydantic models will help ensure our agent returns structured data that we can easily process.

# %%
class WebSearchItem(BaseModel):
    reason: str
    "Your reasoning for why this search is important to the query."

    query: str
    "The search term to use for the web search."

class WebSearchPlan(BaseModel):
    searches: list[WebSearchItem]
    """A list of web searches to perform to best answer the query."""

# %% [markdown]
# Now we'll create our Planner Agent using the Agent class from the OpenAI Agents SDK. This agent will use the instructions defined in `PLANNER_PROMPT` and will output structured data in the form of our WebSearchPlan model. We're using the GPT-4o model for this agent to ensure high-quality search term generation.
#
# > NOTE: When we provide an `output_type` - the model will return a [structured response](https://platform.openai.com/docs/guides/structured-outputs?api-mode=responses).

# %%
planner_agent = Agent(
    name="PlannerAgent",
    instructions=PLANNER_PROMPT,
    model="gpt-4.1",
    output_type=WebSearchPlan,
)

# %% [markdown]
# #### ❓Question #1:
#
# Why is it important to provide a structured response template? (As in: Why are structured outputs helpful/preferred in Agentic workflows?)
#
#
# #### ✅ Answer:
#
# *Structured response templates (like Pydantic models in this notebook) are crucial in agentic workflows for several reasons:*
#
# **Predictability and Reliability:** They ensure the Large Language Model (LLM) returns data in a consistent and expected format. This predictability is vital for programmatic processing. If an agent's output is a free-form text, the downstream components would need complex parsing logic, which can be brittle and error-prone.
#
# **Ease of Processing:** When data is structured (e.g., as a JSON object matching a predefined schema), it's straightforward to access specific pieces of information. For instance, if you know an agent will always return a WebSearchPlan with a list of searches, you can directly iterate over result.final_output.searches as shown in your _plan_searches method.
#
# **Validation:** Structured output schemas allow for automatic validation of the LLM's response. If the LLM fails to adhere to the schema, the error can be caught early, and potentially, a retry mechanism with corrective feedback can be triggered. This improves the robustness of the overall system.
#
# **Inter-Agent Communication:** In multi-agent systems (like the one we are building with a Planner, Searcher, and Writer), structured data ensures that information passed from one agent to another is well-defined and easily consumable. The output of the PlannerAgent (WebSearchPlan) is a clear input for the _perform_searches method.
#
# **Tool Integration:** When agents use tools (like the WebSearchTool), they often need to provide inputs in a specific structure and receive outputs in a structured manner. Structured outputs from the LLM make it easier to prepare these tool inputs and process tool outputs.
#
# **Reduced Hallucinations for Specific Fields:** By instructing the model to fill specific fields, you guide its generation process, which can sometimes reduce the likelihood of it generating irrelevant or "hallucinated" information, as it's constrained by the requested structure.
#
# In essence, structured outputs make agentic workflows more robust, maintainable, and easier to develop by transforming the LLM's potentially unstructured text into a more traditional, developer-friendly data interface.

# %% [markdown]
# ### Task 2: Create Search Agent
#
# Now we'll create our Search Agent, which will be responsible for executing web searches based on the terms generated by the Planner Agent. This agent will take each search query, perform a web search using the `WebSearchTool`, and then summarize the results in a concise format.
#
# > NOTE: We are using the `WebSearchTool`, a hosted tool that can be used as part of an `OpenAIResponsesModel` as outlined in the [documentation](https://openai.github.io/openai-agents-python/tools/). This is based on the tools available through OpenAI's new [Responses API](https://openai.com/index/new-tools-for-building-agents/).
#
# The `SEARCH_PROMPT` below instructs the agent to create brief, focused summaries of search results. These summaries are designed to be 2-3 paragraphs, under 300 words, and capture only the essential information without unnecessary details. The goal is to provide the Writer Agent with clear, distilled information that can be efficiently synthesized into the final report.

# %%
SEARCH_PROMPT = (
    "You are a research assistant. Given a search term, you search the web for that term and"
    "produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300"
    "words. Capture the main points. Write succinctly, no need to have complete sentences or good"
    "grammar. This will be consumed by someone synthesizing a report, so its vital you capture the"
    "essence and ignore any fluff. Do not include any additional commentary other than the summary"
    "itself."
)

# %% [markdown]
# Now we'll create our Search Agent using the Agent class from the OpenAI Agents SDK. This agent will use the instructions defined in `SEARCH_PROMPT` and will utilize the `WebSearchTool` to perform web searches. We're configuring it with `tool_choice="required"` to ensure it always uses the search tool when processing requests.
#
# > NOTE: We can, as demonstrated, indicate how we want our model to use tools. You can read more about that at the bottom of the page [here](https://openai.github.io/openai-agents-python/agents/)

# %%
from agents import WebSearchTool
from agents.model_settings import ModelSettings

search_agent = Agent(
    name="Search agent",
    instructions=SEARCH_PROMPT,
    tools=[WebSearchTool()],
    model_settings=ModelSettings(tool_choice="required"),
)

# %% [markdown]
# #### ❓ Question #2:
#
# What other tools are supported in OpenAI's Responses API?
#
# #### ✅ Answer:
#
# | Built‑in Tool | Assistants API | Responses API | Agents SDK* |
# | --- | --- | --- | --- |
# | **Retrieval / File Search** | ✔️ `file_search` | ✔️ | ✔️ |
# | **Code Interpreter** | ✔️ | 🚧 _on the roadmap_ | ✔️ (only when pointed at Assistants API) |
# | **Web Search** | — | ✔️ `web_search_preview` | ✔️ (when pointed at Responses API) |
# | **Computer Use** <br>(virtual browser / desktop) | — | ✔️ `computer_use_preview` | ✔️ (when pointed at Responses API) |
# | **Custom Function Calls** | ✔️ (JSON‑schema) | ✔️ | ✔️ |
#
# \* **Agents SDK** inherits the tool set of whichever endpoint (Assistants or Responses) you configure it to call.

# %% [markdown]
# ### Task 3: Create Writer Agent
#
# Finally, we'll create our Writer Agent, which will synthesize all the research findings into a comprehensive report. This agent takes the original query and the research summaries from the Search Agent, then produces a structured report with follow-up questions.
#
# The Writer Agent will:
# 1. Create an outline for the report structure
# 2. Generate a detailed markdown report (5-10 pages)
# 3. Provide follow-up questions for further research
#
# We'll define the prompt for this agent in the next cell. This prompt will instruct the Writer Agent on how to synthesize research findings into a comprehensive report with follow-up questions.

# %%
WRITER_PROMPT = (
    "You are a senior researcher tasked with writing a cohesive report for a research query. "
    "You will be provided with the original query, and some initial research done by a research "
    "assistant.\n"
    "You should first come up with an outline for the report that describes the structure and "
    "flow of the report. Then, generate the report and return that as your final output.\n"
    "The final output should be in markdown format, and it should be lengthy and detailed. Aim "
    "for 5-10 pages of content, at least 1000 words.\n"
    "For the follow-up questions, provide exactly 5 unique questions that would help extend "
    "this research. Do not repeat questions."
)

# %% [markdown]
# #### 🏗️ Activity #1:
#
# This prompt is quite generic - modify this prompt to produce a report that is more personalized to either your personal preference, or more appropriate for a specific use case (eg. law domain research)

# %% [markdown]
# ✅ Answer:
#
# The original WRITER_PROMPT is:

# %%
WRITER_PROMPT = (
    "You are a senior researcher tasked with writing a cohesive report for a research query. "
    "You will be provided with the original query, and some initial research done by a research "
    "assistant.\\n"
    "You should first come up with an outline for the report that describes the structure and "
    "flow of the report. Then, generate the report and return that as your final output.\\n"
    "The final output should be in markdown format, and it should be lengthy and detailed. Aim "
    "for 5-10 pages of content, at least 1000 words.\\n"
    "For the follow-up questions, provide exactly 5 unique questions that would help extend "
    "this research. Do not repeat questions."
)

# %% [markdown]
# Here are a couple of examples of how you could modify this prompt:
#
# 1. Modification for a More Engaging, Narrative Style (Personal Preference):
# This prompt aims for a report that reads more like an insightful article, perhaps for a blog or a general audience interested in a deep dive.

# %%
MODIFIED_WRITER_PROMPT_ENGAGING = (
    "You are a curious and insightful writer, crafting an engaging deep-dive article based on a user's query. "
    "You'll receive the original query and a set of research snippets compiled by an assistant. "
    "Your mission is to transform this raw information into a compelling narrative that is both informative and thought-provoking.\\n"
    "First, devise a clear and logical outline for the article. Think about how to structure the content to best tell a story or explain complex topics in an accessible way. "
    "Then, write the article in markdown format. It should be rich in detail, well-explained, and explore the topic thoroughly, aiming for approximately 1000-1500 words. "
    "Strive for a tone that's engaging, using clear language and avoiding overly academic jargon unless essential (and then explain it simply). "
    "Weave in interesting facts or perspectives from the research to keep the reader hooked.\\n"
    "To spark further curiosity, conclude with exactly 5 unique and insightful open-ended questions that encourage deeper reflection or exploration of the topic by the reader. Make them stimulating and avoid simple yes/no questions."
)

# %% [markdown]
# *Key changes:*
#
# Persona: "Curious and insightful writer" vs. "senior researcher."
#
# Output Style: "Engaging deep-dive article," "compelling narrative" vs. "cohesive report."
#
# Tone: "Informative yet accessible and thought-provoking," "engaging" vs. "formal/implied."
#
# Word Count: Slightly more flexible range.
#
# Follow-up Questions: Emphasis on "open-ended," "stimulating," and encouraging "deeper reflection."

# %% [markdown]
# 2. Modification for a Specific Use Case: Legal Domain Research Memorandum
#
# This prompt is tailored for generating a report in the style of a legal memorandum.

# %%
MODIFIED_WRITER_PROMPT_LEGAL = (
    "You are a meticulous legal analyst tasked with preparing a comprehensive memorandum in response to a specific legal research query. "
    "You will be provided with the original query and summarized findings from preliminary legal research conducted by an assistant.\\n"
    "Your primary objective is to synthesize this information into a formal legal memorandum. "
    "First, you must develop a standard legal memorandum outline: I. Statement of Facts (if applicable, based on query/research, and clearly note if facts are assumed or provided), II. Issues Presented (derived from the query), III. Brief Analysis/Discussion of Research Findings (for each issue, discussing relevant statutes, case law, or legal principles found in the research), IV. Application of Research to Query (applying the analyzed findings to the specifics of the query), V. Conclusion (summarizing the findings and potential implications based on the research). \\n"
    "Generate the memorandum in markdown format. It must be detailed, precise, and well-supported by the provided research, aiming for approximately 1000-2000 words. Maintain a formal, objective, and analytical tone throughout. Clearly attribute information to the research provided (e.g., 'According to research summary X...'). Do not introduce external legal knowledge beyond what is provided in the research summaries.\\n"
    "Conclude by identifying exactly 5 specific and distinct points of further legal inquiry or unresolved questions that arise directly from the initial research and its application to the query. These should highlight areas needing deeper investigation, factual clarification, or more nuanced legal interpretation relevant to the matter."
)

# %% [markdown]
# *Key changes:*
#
# Persona: "Meticulous legal analyst" vs. "senior researcher."
#
# Output Style: "Comprehensive legal memorandum" vs. "cohesive report."
# Structure: Very specific outline mandated (Statement of Facts, Issues Presented, etc.).
#
# Tone: "Formal, objective, and analytical."
#
# Content Constraints: Emphasis on using only provided research, citing it, and not introducing external knowledge.
#
# Word Count: Adjusted slightly.
#
# Follow-up Questions: Framed as "points of further legal inquiry" or "unresolved questions" directly relevant to the legal context.

# %% [markdown]
# Now we'll create our Writer Agent using the Agent class from the OpenAI Agents SDK. This agent will synthesize all the research findings into a comprehensive report. We're configuring it with the `ReportData` output type to structure the response with a short summary, markdown report, and follow-up questions.

# %%
class ReportData(BaseModel):
    short_summary: str
    """A short 2-3 sentence summary of the findings."""

    markdown_report: str
    """The final report"""

    follow_up_questions: list[str]
    """Suggested topics to research further"""

# %% [markdown]
# Now we'll define our Writer Agent using the Agent class from the OpenAI Agents SDK. This agent will take the original query and research summaries, then synthesize them into a comprehensive report with follow-up questions. We've defined a custom output type called `ReportData` that structures the response with a short summary, markdown report, and follow-up questions.

# %%
writer_agent = Agent(
    name="WriterAgent",
    instructions=WRITER_PROMPT,
    model="o3-mini",
    output_type=ReportData,
)

# %% [markdown]
# #### ❓ Question #3:
#
# Why are we electing to use a reasoning model for writing our report?
#
# #### ✅ Answer:
#
# We are electing to use a model like "o3-mini" (which is a "reasoning model" in the context of the writer_agent) for writing the report because the task of report generation requires several capabilities that these types of models are designed for:
#
# **Synthesis of Information:** The writer_agent is tasked with taking the original query and a list of summarized search results and creating a "cohesive report." This requires understanding the nuances of the gathered information, identifying key themes, and weaving them together into a coherent narrative. Reasoning models are better at this complex synthesis than models primarily designed for simpler, more direct Q&A or classification.
#
# **Structuring Content:** The prompt for the writer_agent explicitly asks it to "first come up with an outline for the report that describes the structure and flow of the report. Then, generate the report..." This ability to plan, outline, and then flesh out sections is a hallmark of more advanced reasoning capabilities.
#
# **Long-Form Generation:** The requirement for a "lengthy and detailed" report (5-10 pages, at least 1000 words) necessitates a model that can maintain coherence, context, and logical flow over an extended piece of text. Reasoning models are generally better at generating high-quality, long-form content.
#
# **Generating Follow-Up Questions:** The task also includes providing "exactly 5 unique questions that would help extend this research." This requires not just understanding the content but also thinking critically about its implications and identifying areas for further exploration. This is an inferential task that benefits from a model with stronger reasoning abilities.
#
# **Adherence to Complex Instructions:** The WRITER_PROMPT is quite detailed, specifying the persona (senior researcher), output format (markdown), length, and specific requirements for follow-up questions. Reasoning models are typically more capable of understanding and adhering to such complex, multi-part instructions.
#
# *While simpler models might be able to generate text, a "reasoning model" is chosen here for its superior ability to understand context deeply, plan a complex output, synthesize diverse pieces of information logically, and generate nuanced, well-structured, and extensive content that fulfills the sophisticated requirements of the writer_agent.*

# %% [markdown]
# ## Task 4: Create Utility Classes
#
# We'll define utility classes to help with displaying progress and managing the research workflow. The Printer class below will provide real-time updates on the research process.

# %% [markdown]
# The Printer class provides real-time progress updates during the research process. It uses Rich's Live display to show dynamic content with spinners for in-progress items and checkmarks for completed tasks. The class maintains a dictionary of items with their completion status and can selectively hide checkmarks for specific items. This creates a clean, interactive console experience that keeps the user informed about the current state of the research workflow.

# %%
from typing import Any

from rich.console import Console, Group
from rich.live import Live
from rich.spinner import Spinner

class Printer:
    def __init__(self, console: Console):
        self.live = Live(console=console)
        self.items: dict[str, tuple[str, bool]] = {}
        self.hide_done_ids: set[str] = set()
        self.live.start()

    def end(self) -> None:
        self.live.stop()

    def hide_done_checkmark(self, item_id: str) -> None:
        self.hide_done_ids.add(item_id)

    def update_item(
        self, item_id: str, content: str, is_done: bool = False, hide_checkmark: bool = False
    ) -> None:
        self.items[item_id] = (content, is_done)
        if hide_checkmark:
            self.hide_done_ids.add(item_id)
        self.flush()

    def mark_item_done(self, item_id: str) -> None:
        self.items[item_id] = (self.items[item_id][0], True)
        self.flush()

    def flush(self) -> None:
        renderables: list[Any] = []
        for item_id, (content, is_done) in self.items.items():
            if is_done:
                prefix = "✅ " if item_id not in self.hide_done_ids else ""
                renderables.append(prefix + content)
            else:
                renderables.append(Spinner("dots", text=content))
        self.live.update(Group(*renderables))

# %% [markdown]
# Let's create a ResearchManager class that will orchestrate the research process. This class will:
# 1. Plan searches based on the query
# 2. Perform those searches to gather information
# 3. Write a comprehensive report based on the gathered information
# 4. Display progress using our Printer class

# %%
from __future__ import annotations

import asyncio
import time

from agents import Runner, custom_span, gen_trace_id, trace

class ResearchManager:
    def __init__(self):
        self.console = Console()
        self.printer = Printer(self.console)

    async def run(self, query: str) -> None:
        trace_id = gen_trace_id()
        with trace("Research trace", trace_id=trace_id):
            self.printer.update_item(
                "trace_id",
                f"View trace: https://platform.openai.com/traces/trace?trace_id={trace_id}",
                is_done=True,
                hide_checkmark=True,
            )

            self.printer.update_item(
                "starting",
                "Starting research...",
                is_done=True,
                hide_checkmark=True,
            )
            search_plan = await self._plan_searches(query)
            search_results = await self._perform_searches(search_plan)
            report = await self._write_report(query, search_results)

            final_report = f"Report summary\n\n{report.short_summary}"
            self.printer.update_item("final_report", final_report, is_done=True)

            self.printer.end()

        print("\n\n=====REPORT=====\n\n")
        print(f"Report: {report.markdown_report}")
        print("\n\n=====FOLLOW UP QUESTIONS=====\n\n")
        unique_questions = []
        seen = set()

        for question in report.follow_up_questions:
            if question not in seen:
                unique_questions.append(question)
                seen.add(question)

        for i, question in enumerate(unique_questions, 1):
            print(f"{i}. {question}")

    async def _plan_searches(self, query: str) -> WebSearchPlan:
        self.printer.update_item("planning", "Planning searches...")
        result = await Runner.run(
            planner_agent,
            f"Query: {query}",
        )
        self.printer.update_item(
            "planning",
            f"Will perform {len(result.final_output.searches)} searches",
            is_done=True,
        )
        return result.final_output_as(WebSearchPlan)

    async def _perform_searches(self, search_plan: WebSearchPlan) -> list[str]:
        with custom_span("Search the web"):
            self.printer.update_item("searching", "Searching...")
            num_completed = 0
            max_concurrent = 5
            results = []

            for i in range(0, len(search_plan.searches), max_concurrent):
                batch = search_plan.searches[i:i+max_concurrent]
                tasks = [asyncio.create_task(self._search(item)) for item in batch]

                for task in asyncio.as_completed(tasks):
                    try:
                        result = await task
                        if result is not None:
                            results.append(result)
                    except Exception as e:
                        print(f"Search error: {e}")

                    num_completed += 1
                    self.printer.update_item(
                        "searching", f"Searching... {num_completed}/{len(search_plan.searches)} completed"
                    )

            self.printer.mark_item_done("searching")
            return results

    async def _search(self, item: WebSearchItem) -> str | None:
        input = f"Search term: {item.query}\nReason for searching: {item.reason}"
        try:
            result = await Runner.run(
                search_agent,
                input,
            )
            return str(result.final_output)
        except Exception as e:
            print(f"Error searching for '{item.query}': {e}")
            return None

    async def _write_report(self, query: str, search_results: list[str]) -> ReportData:
        self.printer.update_item("writing", "Thinking about report...")
        input = f"Original query: {query}\nSummarized search results: {search_results}"

        result = Runner.run_streamed(
            writer_agent,
            input,
        )

        update_messages = [
            "Thinking about report...",
            "Planning report structure...",
            "Writing outline...",
            "Creating sections...",
            "Cleaning up formatting...",
            "Finalizing report...",
            "Finishing report...",
        ]

        last_update = time.time()
        next_message = 0

        async for event in result.stream_events():
            if time.time() - last_update > 5 and next_message < len(update_messages):
                self.printer.update_item("writing", update_messages[next_message])
                next_message += 1
                last_update = time.time()

        self.printer.mark_item_done("writing")
        return result.final_output_as(ReportData)

# %% [markdown]
# #### 🏗️ Activity #2:
#
# Convert the above flow into a flowchart style image (software of your choosing, but if you're not sure which to use try [Excallidraw](https://excalidraw.com/)) that outlines how the different Agents interact with each other.
#
# > HINT: Cursor's CMD+L (CTRL+L on Windows) would be a helpful way to get a basic diagram that you can add more detail to!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Task 5: Running Our Agent
#
# Now let's run our agent! The main function below will prompt the user for a research topic, then pass that query to our ResearchManager to handle the entire research process. The ResearchManager will:
#
# 1. Break down the query into search items
# 2. Search for information on each item
# 3. Write a comprehensive report based on the search results
#
# Let's see it in action!

# %%
async def main() -> None:
    query = input("What would you like to research? ")
    await ResearchManager().run(query)

# %%
asyncio.run(main())
# Out:
# What would you like to research? 8th to 16th Century Bharat
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# =====REPORT=====
#
#
# Report: # 8th to 16th Century Bharat: A Tapestry of Dynasties, Cultural Synthesis, and Transformation
#
# This report presents a comprehensive study of Bharat (India) during the period from the 8th to the 16th century. Over these eight centuries, the subcontinent experienced dramatic political, religious, cultural, and economic transformations. An array of dynasties rose and fell, each contributing to the complex mosaic of Indian history. This document is structured to provide insights into the political landscape, religious innovations, art and architecture, social transformations, and scientific advancements that defined medieval India.
#
# ---
#
# ## 1. Introduction
#
# Between the 8th and 16th centuries, India was a stage for dynamic changes and remarkable achievements. Politically, numerous empires and kingdoms vied for control over vast territories, while cultural and religious ideas flowed across regions. Scholars, artists, and architects synthesized local traditions with influences from Persia, Central Asia, and Europe, giving rise to distinctive art, architecture, and administrative systems that continue to influence India today.
#
# This report is organized into several key themes: the evolution of political power, religious and philosophical transformations, the flourishing of art and architecture, shifts in the socioeconomic order, and the impactful contributions in science and technology. We also examine the evolution of military strategies and the status of social groups, including a focus on the evolving condition of women during this transformative era.
#
# ---
#
# ## 2. Political Landscape and Dynastic Rule
#
# ### 2.1 Early Medieval Kingdoms and Empires
#
# The early part of this historical period saw the dominance of regional kingdoms whose rule extended across northern, southern, and central India. The Gurjara-Pratihara dynasty, for example, not only defended northern India against external invasions such as those from the Arabs but also patronized the arts, exemplified by the exquisite Khajuraho temples. Similarly, the Rashtrakuta dynasty in the Deccan played a significant role in promoting art and architecture, with monuments like the Kailasanatha temple at Ellora standing testimony to their legacy.
#
# ### 2.2 The Southern Dynasties
#
# In South India, the Chola dynasty emerged as a powerhouse. Under the guidance of rulers such as Rajaraja Chola I and Rajendra Chola I, the empire expanded its influence regionally and internationally. Monumental constructions like the Brihadeeswarar Temple in Thanjavur and the iconic Nataraja bronzes are enduring symbols of the Chola's contributions to art and architecture. Concurrently, the Hoysala Empire cultivated a unique style seen in the intricately carved temples of Belur and Halebidu.
#
# ### 2.3 The Arrival and Ascendancy of Islamic Rule
#
# From the 12th century onward, various Islamic dynasties began to leave their imprint on the Indian political map. The establishment of the Delhi Sultanate marked the beginning of a new era, characterized by a fusion of Persian, Afghan, and Indian elements in administration and culture. The Sultanate witnessed powerful rulers like Iltutmish and Tughluq who enhanced centralization but also faced military challenges from invading forces, including the Mongols and Timur. The later phase saw the rise of the Mughal Empire, with Babur’s victory at the First Battle of Panipat in 1526 paving the way for an era of centralized administration, economic reforms, and cultural synthesis under subsequent emperors like Akbar.
#
# ### 2.4 The Vijayanagara Empire: A Hindu Renaissance
#
# In the southern regions, the Vijayanagara Empire emerged in the 14th century as a strategic response to northern Islamic expansion. This empire not only provided a bulwark against invasions but also sparked a renaissance in art, literature, and temple architecture. Hampi, the capital of Vijayanagara, became synonymous with economic vigor, cultural pluralism, and architectural grandeur. The blend of religious symbolism and robust military governance defined the political landscape of the South during this period.
#
# ---
#
# ## 3. Religious and Philosophical Transformations
#
# The period witnessed profound religious shifts, marked by the advent of new devotional movements and intellectual discourses that challenged established religious practices.
#
# ### 3.1 The Bhakti Movement
#
# Emerging in South India between the 7th and 9th centuries, the Bhakti movement was characterized by its emphasis on personal devotion and the rejection of ritualistic formalities. Saint-poets such as the Nayanars and Alvars, who belonged to diverse social backgrounds including marginalized communities, composed moving hymns that celebrated devotion over caste distinctions. The influence of the Bhakti movement was far-reaching, leading to the establishment of temple traditions in regions ruled by the Chola and Pandya dynasties.
#
# ### 3.2 Influence of Philosophers
#
# The evolution of Hindu thought was significantly influenced by thinkers like Shankaracharya and Ramanujacharya. Shankaracharya’s advocacy of Advaita or non-dualism posited the idea of oneness, suggesting that the material world was an illusion (maya) that veiled the true unity of the self with the divine. In contrast, Ramanujacharya’s Vishishtadvaita emphasized a qualified non-dualism where the soul retained its distinct identity even as it unified with the Supreme. These intellectual debates laid the groundwork for a more personalized approach to spirituality, deeply influencing devotional practices and religious art.
#
# ### 3.3 The Rise of Sufism
#
# Parallel to the Bhakti movement, Sufism found fertile ground in medieval India. Sufi mystics such as those of the Chishti order emphasized inner love, mysticism, and the universality of the divine. Sufi saints became renowned for promoting religious tolerance and forging cultural connections between Islamic and local traditions, setting the stage for an enduring legacy of spiritual syncretism in the subcontinent.
#
# ---
#
# ## 4. Art, Architecture, and Cultural Synthesis
#
# ### 4.1 Temple Architecture and Sculpture
#
# Indian art and architecture during the medieval period represented a critical fusion of regional traditions with pan-Indian influences. Remarkable examples include the open pavilion-style temples of the Pratihara period, the elegant and massive structures crafted by the Cholas, and the distinctive Hoysala style present in Karnataka’s intricately carved stone temples. The enduring legacy of these styles can be seen, for instance, in the Khajuraho and Brihadeeswarar temples, which attract admirers from around the world.
#
# ### 4.2 Islamic Contributions to Architecture
#
# The advent of Islamic rule and the Delhi Sultanate introduced new architectural motifs into the Indian landscape. Structures like the Qutb Minar and the Jāmiʿ Masjid in Ahmedabad exhibit a striking blend of Persian, Afghan, and indigenous Indian styles. Features such as arches, domes, and intricate geometrical patterns became widespread, symbolizing a period in which architecture served as a vehicle for cultural dialogue.
#
# ### 4.3 Synthesis in the Arts
#
# Beyond architecture, the fusion of artistic styles was evident in sculpture, painting, and literature. Court patronage under the Mughal emperors, for example, triggered a renaissance in miniature painting where Persian influences merged with indigenous aesthetics. Additionally, the integration of local artisans and techniques with foreign methodologies helped create a unique cultural tapestry, further enriching Indian art and literature.
#
# ---
#
# ## 5. Socio-Economic Developments and Trade Networks
#
# ### 5.1 Vibrant Trade and Commerce
#
# Medieval India was at the crossroads of international trade, with bustling ports along the Malabar and Coromandel coasts connecting the region to Southeast Asia, the Middle East, and beyond. Indian merchants traded a variety of goods including spices, textiles, and precious stones. The flourishing spice trade particularly played a pivotal role in connecting India to Mediterranean markets and fueling economic prosperity.
#
# ### 5.2 Role of Trade Guilds
#
# Trade guilds, especially in southern regions, operated as semi-autonomous economic units. These guilds, such as the Ayyavole, facilitated trade, financed local projects, and even engaged in temple patronage. Their influence often transcended commercial activities, with positions of power being negotiated with local rulers, thereby integrating economic and political life.
#
# ### 5.3 Agricultural Prosperity and State Reforms
#
# The agrarian base continued to be vital to the subcontinent's economy. Improvements in irrigation, agrarian reforms introduced by rulers like Akbar, and the adoption of uniform taxation systems under the Mughal empire contributed to significant enhancements in agricultural productivity. These reforms not only bolstered economic stability but also facilitated the integration of diverse regions under centralized administration.
#
# ---
#
# ## 6. Social Structures and the Evolving Caste System
#
# The medieval era witnessed a gradual but complex transformation of India’s traditional social framework. While the varna system had long organized society, the growth of numerous jatis (sub-castes) based on occupation, lineage, and regional influences contributed to a more intricate social architecture.
#
# ### 6.1 Fluidity and Rigidity in Caste Dynamics
#
# Interactions among diverse communities, combined with the socio-political pressures from ruling dynasties, led to both the flexibility and eventual rigidity of the caste system. Some innovations, like inter-caste marriages and the formation of mixed castes, demonstrated the evolving nature of social identities. However, with the advent of Islamic and later Mughal rule, some of these flexible boundaries began to harden, setting the stage for the more rigid hierarchies observed in later centuries.
#
# ### 6.2 The Status of Women
#
# One of the most critically examined aspects of this period is the changing status of women. Over time, traditional patriarchal norms were reinforced, leading to practices such as child marriage, purdah, sati, and the devadasi system. Yet, amidst this general trend, some remarkable exceptions emerged. Celebrated figures like Razia Sultana, the only female ruler of Delhi, as well as influential devotional poets such as Mirabai and Akka Mahadevi, defied societal constraints and left an indelible mark on history.
#
# ---
#
# ## 7. Scientific and Technological Advancements
#
# Medieval India was also a hub of scientific inquiry and technological innovation. This era witnessed significant contributions in mathematics, astronomy, medicine, and metallurgy as indigenous knowledge systems merged with external influences.
#
# ### 7.1 Contributions in Mathematics and Astronomy
#
# Pioneers like Bhāskara II and Parameshvara Nambudiri advanced mathematical and astronomical knowledge through seminal works that introduced methods for solving equations, forecasting astronomical events, and refining observational techniques. The cyclic Chakravala method and early forms of differential calculus were some of the notable contributions emerging from this period.
#
# ### 7.2 Advances in Medicine and Technology
#
# The tradition of Ayurveda continued to evolve, with compilations like the Charaka Samhita and Sushruta Samhita underpinning medical practices. Educational institutions such as maktabs and madrasas further enhanced scientific inquiry. Alongside these intellectual developments, technological innovations in textile production (such as the spinning wheel), water management, and metallurgy significantly influenced economic productivity and military capabilities.
#
# ---
#
# ## 8. Military Conflicts and Strategic Engagements
#
# ### 8.1 Evolution of Battle Tactics
#
# Several landmark battles punctuated this period, highlighting the evolving nature of military strategies and the integration of new technologies such as gunpowder weapons. The First Battle of Tarain (1191) and its subsequent rematch in 1192 illustrated the dramatic shifts in power dynamics that resulted in the establishment of subsequent Muslim dominions in northern India.
#
# ### 8.2 Key Battles and Their Implications
#
# The use of artillery and field fortifications became prominent by the time of the First Battle of Panipat in 1526, where Babur’s innovative tactics undercut Ibrahim Lodi’s forces. Later, battles such as Khanwa (1527) and Talikota (1565) further showcased how alliances, new weaponry, and strategic military planning not only decided the fate of empires but also reshaped the geopolitical contours of Bharat.
#
# ---
#
# ## 9. Conclusion
#
# The centuries spanning from the 8th to the 16th marked a period of remarkable transformation in Bharat. The rise and fall of dynasties, the evolution of religious thought through the Bhakti and Sufi movements, and groundbreaking advancements in art, architecture, and science collectively forged the diverse and rich tapestry that characterizes modern India. Despite the turbulent challenges of invasions and socio-political upheavals, these transformations laid the cultural and intellectual foundations that continued to influence the subcontinent in later centuries.
#
# This multifaceted synthesis of indigenous traditions with foreign influences not only enriched the cultural fabric of medieval India but also provided enduring legacies that continue to be celebrated today.
#
# ---
#
# ## 10. Future Directions and Research Opportunities
#
# Further study is encouraged in several areas. Researchers might explore in greater detail the lesser-known kingdoms and regional variations, the impact of trade networks on cultural exchanges, or the technological innovations that spurred economic development. Understanding these nuances can provide a deeper appreciation of the intricate interplay between different facets of Indian society during this transformative era.
#
# In sum, the period from the 8th to the 16th century serves as a compelling case study of resilience, adaptation, and creative synthesis—a period that continues to influence modern India's identity on the global stage.
#
#
#
# =====FOLLOW UP QUESTIONS=====
#
#
# 1. How did regional variations influence the architectural styles across different Indian dynasties during this period?
# 2. What role did trade guilds play in shaping the economic policies of medieval Indian kingdoms?
# 3. In what ways did the Bhakti and Sufi movements contribute to social reform and religious tolerance in medieval India?
# 4. How did military innovation, especially the adoption of gunpowder and artillery, transform warfare in this era?
# 5. What lasting impacts did medieval advancements in science and technology have on subsequent periods of Indian history?

# %% [markdown]
# ---
#
# ## Sample Report in Markdown
#
# ---

# %% [markdown]
# # OpenAI Agents SDK: A Comprehensive Report
#
# *Published: October 2023*
#
# ## Table of Contents
#
# 1. [Introduction](#introduction)
# 2. [Core Concepts and Key Features](#core-concepts-and-key-features)
# 3. [Architecture and Developer Experience](#architecture-and-developer-experience)
# 4. [Comparative Analysis with Alternative Frameworks](#comparative-analysis-with-alternative-frameworks)
# 5. [Integrations and Real-World Applications](#integrations-and-real-world-applications)
# 6. [Troubleshooting, Observability, and Debugging](#troubleshooting-observability-and-debugging)
# 7. [Community Impact and Future Directions](#community-impact-and-future-directions)
# 8. [Conclusion](#conclusion)
#
# ---
#
# ## Introduction
#
# In March 2025, OpenAI released the Agents SDK, a groundbreaking, open-source framework aimed at simplifying the development of autonomous AI agents capable of performing intricate tasks with minimal human intervention. Designed with a Python-first approach, the SDK offers a minimal set of abstractions, yet provides all the necessary components to build, debug, and optimize multi-agent workflows. The release marked a significant milestone for developers who seek to integrate large language models (LLMs) with advanced task delegation mechanisms, enabling next-generation automation in various industries.
#
# The primary goal of the OpenAI Agents SDK is to streamline the creation of agentic applications by offering core primitives such as *agents*, *handoffs*, and *guardrails*. These primitives are essential for orchestrating autonomous AI systems that perform key functions such as web search, file operations, and even actions on a computer. This report delves into the SDK's features, its operational architecture, integration capabilities, and how it compares to other frameworks in the rapidly evolving landscape of AI development tools.
#
# ## Core Concepts and Key Features
#
# ### Agents
#
# At the heart of the SDK are **agents**—intelligent entities that encapsulate a specific set of instructions and tools. Each agent is built on top of a large language model and can be customized with its own personality, domain expertise, and operational directives. For example, a "Math Tutor" agent could be designed to solve math problems by explaining each step clearly.
#
# **Key elements of an agent include:**
#
# - **Instructions:** Specific guidelines that shape the agent's responses and behavior in the context of its designated role.
# - **Tools:** Predefined or dynamically integrated tools that the agent can leverage to access external resources (e.g., web search or file search functionalities).
#
# ### Handoffs
#
# A unique feature introduced by the SDK is the concept of **handoffs**. Handoffs allow agents to delegate tasks to one another based on expertise and contextual needs. This orchestration paves the way for sophisticated workflows where multiple agents work in tandem, each contributing its specialized capabilities to complete a complex task.
#
# ### Guardrails
#
# Safety and reliability remain a cornerstone in AI development, and the SDK introduces **guardrails** as a means of controlling input and output validation. Guardrails help ensure that agents operate within defined safety parameters, preventing unintended actions and mitigating risks associated with autonomous decision-making.
#
# ### Built-in Debugging and Observability
#
# The development process is further enhanced by built-in **tracing and visualization tools**. These tools offer real-time insights into agent interactions, tool invocations, and decision-making pathways, thereby making debugging and optimization more accessible and systematic. The tracing functionality is a vital feature for developers looking to fine-tune agent performance in production environments.
#
# ## Architecture and Developer Experience
#
# ### Python-First Approach
#
# The SDK is inherently Python-based, making it highly accessible to the vast community of Python developers. By leveraging existing language features without introducing excessive abstractions, the SDK provides both simplicity and power. The installation is straightforward:
#
# ```bash
# mkdir my_project
# cd my_project
# python -m venv .venv
# source .venv/bin/activate
# pip install openai-agents
# ```
#
# Once installed, developers can create and configure agents with minimal boilerplate code. The emphasis on a minimal learning curve has been a significant point of praise among early adopters.
#
# ### Developer Tools and Tutorials
#
# In addition to comprehensive official documentation available on OpenAI’s GitHub pages, the community has contributed numerous tutorials and code examples. Video tutorials by experts such as Sam Witteveen and James Briggs provide hands-on demonstrations, ranging from simple agent creation to more sophisticated scenarios involving parallel execution and advanced tool integrations.
#
# ### Use of Python's Ecosystem
#
# The integration with Python’s ecosystem means that developers can immediately apply a range of established libraries and frameworks. For instance, utilizing Pydantic for input validation in guardrails or leveraging visualization libraries to display agent workflows are examples of how the SDK embraces the strengths of Python.
#
# ## Comparative Analysis with Alternative Frameworks
#
# While the OpenAI Agents SDK has received acclaim for its simplicity and robust integration with OpenAI’s ecosystem, other frameworks such as LangGraph, CrewAI, and AutoGen have emerged as viable alternatives. Here’s how they compare:
#
# - **LangGraph:** Known for its graph-based architecture, LangGraph is ideal for handling complex and cyclical workflows that require sophisticated state management. However, it comes with a steeper learning curve, making it less accessible for projects that require quick prototyping.
#
# - **CrewAI:** Emphasizing a role-based multi-agent system, CrewAI excels in scenarios where collaboration among agents is critical. Its design promotes clear segregation of duties among different agents, which can be beneficial in customer service or large-scale business automation.
#
# - **AutoGen:** This framework supports flexible conversation patterns and diverse agent interactions, particularly useful in applications where adaptive dialogue is essential. Nevertheless, AutoGen may introduce additional overhead when managing state and coordinating multiple agents.
#
# In contrast, the OpenAI Agents SDK strikes an effective balance by offering a lightweight yet powerful toolset geared towards production readiness. Its strengths lie in its minimal abstractions, ease of integration with various tools (like web search and file search), and built-in observability features that are crucial for debugging and tracing agent interactions.
#
# ## Integrations and Real-World Applications
#
# ### Diverse Integrations
#
# The real power of the OpenAI Agents SDK surfaces when it is integrated with other systems and platforms. Notable integrations include:
#
# - **Box Integration:** Enhancing enterprise content management, Box has adopted the SDK to enable secure AI-powered data processing. This integration allows agents to reliably access and interpret proprietary data.
#
# - **Coinbase AgentKit:** With financial capabilities in mind, Coinbase introduced AgentKit, leveraging the SDK to incorporate financial operations and risk analysis directly into AI agents.
#
# - **Milvus and Ollama:** These integrations allow the SDK to handle high-performance data queries and run agents on local infrastructure respectively, ensuring both speed and privacy.
#
# ### Real-World Applications
#
# The versatility of the SDK lends itself to a multitude of applications:
#
# - **Customer Support:** Automated agents can be built to handle customer inquiries, providing faster and more accurate responses while reducing workload on human agents.
#
# - **Content Generation:** In marketing and media, agents can generate high-quality articles, detailed reports, and even code reviews with built-in content guidelines.
#
# - **Financial Analysis:** Specialized agents capable of real-time data fetching and market analysis can generate actionable insights for investors and analysts.
#
# - **Health and Wellness:** Custom agents can handle tasks such as appointment scheduling, patient record management, and even provide personalized fitness and dietary recommendations.
#
# - **Educational Tools:** Intelligent tutoring agents can assist students by providing personalized learning experiences and instant feedback on assignments.
#
# These applications underscore the SDK’s transformative potential across various industries, driving the trend towards increased automation and efficiency.
#
# ## Troubleshooting, Observability, and Debugging
#
# ### Common Issues and Solutions
#
# As with any cutting-edge technology, developers working with the OpenAI Agents SDK have encountered challenges:
#
# - **API Key Management:** Authentication errors due to missing or invalid API keys are common. The solution involves ensuring that the `OPENAI_API_KEY` environment variable is correctly set or programmatically configured using OpenAI’s helper functions.
#
# - **Rate Limitations:** Rate limits, an intrinsic challenge with API-based services, require developers to monitor dashboard usage and implement retry strategies with exponential backoff.
#
# - **Response Delays:** Network latency and high server loads can result in unexpected delays. Developers are advised to check network settings, adhere to best practices in setting request timeouts, and monitor OpenAI’s service status.
#
# ### Built-In Tracing Capabilities
#
# The SDK provides robust tracing tools that log agent inputs, outputs, tool interactions, and error messages. This level of observability is crucial for debugging complex workflows and allows developers to visualize the agent’s decision-making process in real time. By configuring a `TracingConfig` object, developers can capture detailed insights and identify performance bottlenecks.
#
# ### Best Practices
#
# - **Prompt Engineering:** Refine prompts to reduce ambiguity and minimize unexpected outputs.
# - **Layered Validation:** Use guardrails extensively to ensure inputs and outputs are verified at multiple layers.
# - **Modular Design:** Break complex tasks into smaller, more manageable components using handoffs to delegate tasks appropriately.
#
# ## Community Impact and Future Directions
#
# ### Developer and Enterprise Adoption
#
# The release of the OpenAI Agents SDK has been met with enthusiasm within the developer community. Its ease of use, combined with comprehensive documentation and community-driven resources (such as tutorials on Class Central and DataCamp), has accelerated its adoption across educational, enterprise, and research sectors.
#
# Several leading organizations, including Box and Coinbase, have integrated the SDK into their workflows, demonstrating its capability to drive real-world business solutions. The open-source nature of the SDK, licensed under the MIT License, further encourages widespread industrial collaboration and innovation.
#
# ### Future Prospects
#
# Looking forward, OpenAI plans to extend the SDK’s support beyond Python, potentially embracing other programming languages like JavaScript. Additionally, future updates are anticipated to expand tool integrations, further enhance safety mechanisms, and streamline the development of multi-agent ecosystems. Planned deprecations of older APIs, such as the Assistants API in favor of the more unified Responses API, underline the SDK’s evolving roadmap aimed at future-proofing agentic applications.
#
# ## Conclusion
#
# The OpenAI Agents SDK represents a significant step forward in the field of AI development. Its lightweight, Python-first framework facilitates the creation of autonomous agents that can handle a wide array of tasks—from simple inquiries to complex multi-agent systems. The SDK’s robust integration capabilities, combined with its focus on safety and observability, make it an ideal choice for both developers and enterprises seeking to build reliable, scalable agentic applications.
#
# In summary, the SDK not only lowers the barrier to entry for developing sophisticated AI applications but also sets the stage for further innovations as the ecosystem evolves. It is poised to become a standard toolkit for the next generation of AI-driven technologies, empowering users across sectors to achieve greater efficiency and creativity in task automation.
#
# ---
#
# *For further reading, developers are encouraged to visit the official OpenAI documentation, join the community forums, and explore real-world use cases to deepen their understanding of this transformative tool.*
